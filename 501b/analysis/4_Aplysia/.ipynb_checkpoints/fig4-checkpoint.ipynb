# %%
import os
import pyabf
import numpy as np
import scipy as sp
from tqdm import tqdm

from scipy.signal import medfilt
from scipy.signal import find_peaks

import matplotlib.pyplot as plt
import glob  
import seaborn as sns
import pandas as pd

# %%
list_of_all_files=(glob.glob("../../data/4_Aplysia/monday/*.abf"))
list_of_all_files
# Out:
# ['../../data/4_Aplysia/monday/21o13000.abf',
#  '../../data/4_Aplysia/monday/21o11005.abf',
#  '../../data/4_Aplysia/monday/21o11003.abf']

# %%
## def values
def_params = {'height':10,'distance':25}

#### utils
def extract_paired(data_path, n_sweeps=21):
    '''
    input: path string
    output: raw data (see dict)
    '''
    data_tmp = pyabf.ABF(data_path)
    sweep_data = []
    
    for sweep in range(n_sweeps):
        
        data_tmp.setSweep(sweepNumber=sweep, channel=0) 
        ch1 = data_tmp.sweepY

        times = data_tmp.sweepX

        # muscle
        data_tmp.setSweep(sweepNumber=sweep, channel=1) 
        ch2 = data_tmp.sweepY
        
        sweep_data.append([times, ch1, ch2])


    return {
            'data':sweep_data,
            'misc':data_tmp,
           }

def filter_data(data_array, kernel_size=1501):
    '''
    
    performs median filtering (low pass filtering) 
    
    input: data array (np array 1d), kernel size (int)
    output: data array (np array 1d, same shape at input), correction (np array 1d, same shape at input)
    '''
    correction = medfilt(data_array, kernel_size=kernel_size)
    filtered_data = data_array - correction + np.median(data_array)
    
    return filtered_data, correction

        
def peak_finding(data_array, active_window, params=def_params):
    '''
    input: data array (np array 1d), 
        active_window [2,1] start and end of the window
        params
    
    '''
    
    peaks_ids,_ = find_peaks(data_array, 
                         height=params['height'], 
                         distance=params['distance'])
    
    
    non_edge_peaks = peaks_ids[np.bitwise_and(peaks_ids>active_window[0], peaks_ids<active_window[1])]
    peak_heights = data_array[non_edge_peaks]

    return non_edge_peaks, peak_heights

# %%
n_sweeps = 21
f_name1 = '../../data/4_Aplysia/wednesday/21o13000.abf'
data1 = extract_paired(f_name1, n_sweeps=n_sweeps)

f_name2 = '../../data/4_Aplysia/wednesday/21o13001.abf'
data2 = extract_paired(f_name2, n_sweeps=n_sweeps)

# %%
# for i in range(n_sweeps):
#     plt.plot(data['data'][i][0], data['data'][i][2])
#     #plt.scatter(data['data'][i][0][all_peaks[i]], data['data'][i][2][all_peaks[i]])
#     plt.show()

# %%
### no sweeps

#filt_data = filter_data(data['data'][0][2])
# # get peaks
non_edge_peaks, peak_heights = peak_finding(filt_data[0], 
                    [14000,60000], 
                    params={'height':np.mean(filt_data[0]),'distance':1000})

# %%
non_edge_peaks
# Out:
# array([15373, 16421, 17421, ..., 56826, 57829, 58975])

# %%
plt.plot(data['data'][0][0], filt_data[0])
plt.scatter(data['data'][0][0][non_edge_peaks], filt_data[0][non_edge_peaks])
plt.xlim(1,6)
# Out:
# (1.0, 6.0)

# %%
all_peaks1 = []
all_filt1 = []

all_peaks2 = []
all_filt2 = []

for i in tqdm(range(n_sweeps)):
    # plot
#     plt.plot(data['data'][i][0], data['data'][i][1])
#     plt.plot(data['data'][i][0], data['data'][i][2])
#     plt.show()

    #filter
    filt_data1 = filter_data(data1['data'][i][2])
    # get peaks
    non_edge_peaks1, peak_heights1 = peak_finding(filt_data1[0], 
                                                [14000,60000], 
                                                params={'height':np.mean(filt_data1[0]),'distance':1000})
    all_peaks1.append(non_edge_peaks1)
    all_filt1.append(filt_data1[0])
    
    
    filt_data2 = filter_data(data2['data'][i][2])
    # get peaks
    non_edge_peaks2, peak_heights2 = peak_finding(filt_data2[0], 
                                                [14000,60000], 
                                                params={'height':np.mean(filt_data2[0]),'distance':1000})
    all_peaks2.append(non_edge_peaks2)
    all_filt2.append(filt_data2[0])
# Out:
# 100%|██████████| 21/21 [04:07<00:00, 11.81s/it]

# %%
for i in range(n_sweeps):

    plt.plot( data['data'][i][0], all_filt[i])
    plt.scatter( data['data'][i][0][all_peaks[i]], all_filt[i][all_peaks[i]])
    plt.xlim(1,5)
    plt.show()

# %%
valid_id =  np.where([len(i)>4 for i in all_peaks])[0]
firing_rate = [(len(i))/5 for i in all_peaks]

# %%
plt.title('F-I curve')
plt.plot(np.linspace(-1.5,1.5,21), np.array(firing_rate))
plt.xlabel('Insereted current (nA)')
plt.ylabel('Mean firing rate (Hz)')
plt.xlim
plt.show()

# %%
firing_rate2 = [(len(i))/5 for i in all_peaks2]

plt.title('F-I curve')
plt.plot(np.linspace(-1.5,1.5,21), np.array(firing_rate2))
plt.xlabel('Insereted current (nA)')
plt.ylabel('Mean firing rate (Hz)')
plt.xlim
plt.show()

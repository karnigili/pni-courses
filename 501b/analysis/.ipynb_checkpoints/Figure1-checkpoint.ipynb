# %%
import matplotlib
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import pyabf
import pandas as pd
from scipy.signal import medfilt

# %%
## Synaptic Connectivity (Paired Recording)
data_path = '../data/1_CrayfishNeuromuscularJunction/lab3/21915000.abf'
data_tmp = pyabf.ABF(data_path)

# %%
print(type(data_tmp))
print(data_tmp)
# Out:
# <class 'pyabf.abf.ABF'>
# ABF (v2.6) with 2 channels (uV, uV), sampled at 10.0 kHz, containing 1 sweep, having no tags, with a total length of 0.19 minutes, recorded without a protocol file.

# %%
data_tmp.setSweep(sweepNumber=0, channel=0) # nerve extracellular recording
nerve_v = data_tmp.sweepY
nerve_label = data_tmp.sweepLabelY

data_tmp.setSweep(sweepNumber=0, channel=1) # muscle intracellular recording
muscle_v = data_tmp.sweepY
muscle_label = data_tmp.sweepLabelY

times = data_tmp.sweepX # time in seconds!  we don't have to worry about the time array

print(nerve_label, nerve_v)
print(muscle_label, muscle_v)
print(times)
# Out:
# Suction (uV) [42.7246 48.2178 48.8281 ... 28.0762 32.959  36.6211]
# analog (uV) [-3.0518 -3.0518 -3.3569 ... -3.3569 -3.0518 -3.0518]
# [ 0.      0.0001  0.0002 ... 11.3661 11.3662 11.3663]

# %%
data_df = pd.DataFrame(columns = ['times','nerve_v','muscle_v'], 
                       data = np.stack([times, nerve_v, muscle_v]).T)

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 5), sharey=False)

sns.lineplot(ax=axes[0], data=data_df, x='times', y='nerve_v')
axes[0].set_title(nerve_label)

sns.lineplot(ax=axes[1], data=data_df, x='times', y='muscle_v')
axes[1].set_title(muscle_label)

plt.tight_layout()

# %%
## zoom in

fig, axes = plt.subplots(2, 1, figsize=(10, 5), sharey=False)

sns.lineplot(ax=axes[0], data=data_df, x='times', y='nerve_v')
axes[0].set_title(nerve_label)

sns.lineplot(ax=axes[1], data=data_df, x='times', y='muscle_v')
axes[1].set_title(muscle_label)

plt.tight_layout()

# %% [markdown]
# filtering

# %%
correction = medfilt(data_df.muscle_v, kernel_size=801)
data_df['muscle_filt'] = data_df.muscle_v - correction + np.median(data_df.muscle_v)

# %%
sns.lineplot(data=data_df, x='times', y='muscle_filt')
# Out:
# <AxesSubplot:xlabel='times', ylabel='muscle_filt'>
